# %% [markdown]
# This plot is the comparison between the real values and prediction values. The score R^2 is about 0.95. Thus this model can predict the graduation rate successfully. In this plot, graduation rate in 11672 cities are sorted from low to high. The red line in this graph links these 11672 points. The blue dots around the red line are the corresponding prediction values. This plot demonstrates that my proposed model is correct.

# %%
from IPython.display import Image
Image('prediction.png')
